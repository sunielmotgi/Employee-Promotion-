# %%
import numpy as np
import pandas as pd

# %%
df2= pd.read_csv('cleandempsm_data.csv')
df2
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 46375         6915  Sales & Marketing  region_14        Bachelor's      m
# 46376         3030         Technology  region_14        Bachelor's      m
# 46377        74592         Operations  region_27  Master's & above      f
# 46378        13918          Analytics   region_1        Bachelor's      m
# 46379        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df3=df2[(df2['is_promoted'] > 0)]
df3
# Out:
#        employee_id         department     region         education gender  \
# 10           49017  Sales & Marketing   region_7        Bachelor's      f
# 33           58304  Sales & Marketing  region_28        Bachelor's      m
# 51           17673  Sales & Marketing   region_4  Master's & above      m
# 57           45624          Analytics  region_31        Bachelor's      m
# 59           24040         Technology  region_22  Master's & above      m
# ...            ...                ...        ...               ...    ...
# 46309        51059  Sales & Marketing   region_2        Bachelor's      m
# 46332        14502         Technology   region_7  Master's & above      m
# 46336         8278        Procurement  region_13        Bachelor's      f
# 46366          994  Sales & Marketing  region_14        Bachelor's      m
# 46370        12592  Sales & Marketing  region_25  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df2
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 46375         6915  Sales & Marketing  region_14        Bachelor's      m
# 46376         3030         Technology  region_14        Bachelor's      m
# 46377        74592         Operations  region_27  Master's & above      f
# 46378        13918          Analytics   region_1        Bachelor's      m
# 46379        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df3['recruitment_channel'].unique()
# Out:
# array(['sourcing', 'other', 'referred'], dtype=object)

# %%
df3.filter(items=['is_promoted'])
# Out:
#        is_promoted
# 10               1
# 33               1
# 51               1
# 57               1
# 59               1
# ...            ...
# 46309            1
# 46332            1
# 46336            1
# 46366            1
# 46370            1
#
# [4071 rows x 1 columns]

# %%
X = df3.iloc[:,1:12]
y = df3['is_promoted']

# %%
X.head(1)
# Out:
#            department    region   education gender recruitment_channel  \
# 10  Sales & Marketing  region_7  Bachelor's      f            sourcing
#
#     no_of_trainings  age  previous_year_rating  length_of_service  awards_won  \
# 10                1   35                   5.0                  3           0
#
#     avg_training_score
# 10                50.0

# %%
y
# Out:
# 10       1
# 33       1
# 51       1
# 57       1
# 59       1
#         ..
# 46309    1
# 46332    1
# 46336    1
# 46366    1
# 46370    1
# Name: is_promoted, Length: 4071, dtype: int64

# %%
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
dm = DataFrameMapper([(['department',LabelEncoder()]),(["education", LabelEncoder()]), (["gender",LabelEncoder()])])

# %%
dm
# Out:
# DataFrameMapper(drop_cols=[],
#                 features=[['department', LabelEncoder()],
#                           ['education', LabelEncoder()],
#                           ['gender', LabelEncoder()]])

# %%
ml = []
ml.append(['mapper',dm])
ml.append(['SC',StandardScaler()])
ml.append(['RF',RandomForestClassifier()])

# %%
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings('ignore')

# %%
model = Pipeline(ml)
model.fit(X,y)
# Out:
# Pipeline(steps=[('mapper',
#                  DataFrameMapper(drop_cols=[],
#                                  features=[['department', LabelEncoder()],
#                                            ['education', LabelEncoder()],
#                                            ['gender', LabelEncoder()]])),
#                 ('SC', StandardScaler()), ['RF', RandomForestClassifier()]])

# %%
dict(df3.iloc[10,1:])
# Out:
# {'department': 'Operations',
#  'region': 'region_13',
#  'education': "Bachelor's",
#  'gender': 'm',
#  'recruitment_channel': 'other',
#  'no_of_trainings': 1,
#  'age': 35,
#  'previous_year_rating': 4.0,
#  'length_of_service': 6,
#  'awards_won': 0,
#  'avg_training_score': 57.0,
#  'is_promoted': 1}

# %%
new ={'department': 'Technology',
 'education': "Master's & above",
 'gender': 'm',
 'no_of_trainings': 1,
 'age': 34,
 'previous_year_rating': 5.0,
 'length_of_service': 7,
 'awards_won': 0,
 'avg_training_score': 78.0
  }

# %%
aa = pd.DataFrame(new,index=[0])
aa
# Out:
#    department         education gender  no_of_trainings  age  \
# 0  Technology  Master's & above      m                1   34
#
#    previous_year_rating  length_of_service  awards_won  avg_training_score
# 0                   5.0                  7           0                78.0

# %%
prediction = model.predict(aa)
print(prediction)
if (prediction [0] == 0):
    print("Is not promoted")
else:
    print("Is promoted")
# Out:
# [1]
# Is promoted

# %%
import pickle
import pandas as pd

# %%
with open("final_model.sav", mode= 'wb') as f1:
    pickle.dump(model,f1)

# %%
#model.predict (aa)
